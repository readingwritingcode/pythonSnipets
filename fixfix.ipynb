# %%
import pandas as pd

# %%
api_key='jfgrbg'

# %%
df=pd.read_json(f'http://clustercien.udea.edu.co/viceinv/{api_key}/InstituLAC.json')

# %%
df.columns
# Out:
# Index(['Group', 'Info_group', 'Members', 'NC_P-ART_IMP_P', 'NC_P-ART_ELE_P',
#        'NC_P-CAP_LIB_P', 'ASC_P-GEN_CONT_IMP_P1', 'ASC_P-EV_CIENT_P',
#        'ASC_P-RED_P', 'ASC_P-INF_TEC_P', 'FRH_P-TES_DOC_P', 'FRH_P-TES_MAST_P',
#        'FRH_P-TES_PREG_P', 'FRH_P-PROY_INV_DES_P', 'FRH_P-PROY_INV_DES_INN_P',
#        'DTI_P-CONP_TEC_P', 'ASC_P-CON_INF_TEC_P', 'FRH_P-PROY_INV_RESP_SOC_P',
#        'FRH_P-ASE_PRG_ACA_P', 'FRH_P-ASE_CRE_CUR_P', 'NC-CAP_LIB',
#        'NC_P-LIB_P', 'ASC_P-EDIC_P', 'NC-LIB', 'NC_P-TRA_FIL_P', 'ASC_P-DC_P',
#        'ASC_P-GEN_CONT_IMP_P6', 'DTI_P-SOFT_P', 'ASC_P-TALL_CRE_P',
#        'ASC_P-DOC_TRAB_P', 'ASC_P-BOL_RES_INV_P', 'DTI_P-REG_NORM_REGL_LEG_P',
#        'NC_P-NOT_CIE_P', 'ASC_P-GEN_CONT_IMP_P5', 'FRH_P-ASE_PRG_ONDAS_P',
#        'DTI_P-INN_PROC_P', 'DTI_P-INN_GES_EMP_P', 'DTI_P-PLT_PIL_P',
#        'NC_P-PAT_P', 'DTI_P-PRT_IND_P', 'DTI_P-PROT_VIG_EPID_P',
#        'ASC_P-GEN_CONT_IMP_P7', 'NC_P-PRD_INV_ART_P', 'FRH_P-PROY_INV_CRE_P',
# ...

# %%
df
# Out:
#                                                  Group  \
# 0    {'Nombre del grupo': 'Grupo Tandem en Nano-bio...
# 1    {'Nombre del grupo': 'Psicología Dinámica', 'N...
# 2    {'Nombre del grupo': 'Microeconomía Aplicada',...
# 3    {'Nombre del grupo': 'Economía de la Salud', '...
# 4    {'Nombre del grupo': 'Grupo de investigación e...
# ..                                                 ...
# 319  {'Nombre del grupo': 'Aplicaciones Estadística...
# 320  {'Nombre del grupo': 'Determinantes sociales y...
# 321  {'Nombre del grupo': 'Impacto de componentes a...
# 322  {'Nombre del grupo': 'Gestión de Servicios de ...
# 323  {'Nombre del grupo': 'Promoción de la Salud', ...
#
#                                             Info_group  \
# 0    {'Fecha de última actualización': '(Fecha de ú...
# 1    {'Fecha de última actualización': '(Fecha de ú...
# 2    {'Fecha de última actualización': '(Fecha de ú...
# 3    {'Fecha de última actualización': '(Fecha de ú...
# ...

# %%
df.loc[10:20]
# Out:
#                                                 Group  \
# 10  {'Nombre del grupo': 'Poder y Nuevas Subjetivi...
# 11  {'Nombre del grupo': 'Contracampo: grupo de in...
# 12  {'Nombre del grupo': 'Grupo de Investigación e...
# 13  {'Nombre del grupo': 'Estudios Interdisciplina...
# 14  {'Nombre del grupo': 'Colombia: tradiciones de...
# 15  {'Nombre del grupo': 'Instrumentación Científi...
# 16  {'Nombre del grupo': 'Grupo de Investigación e...
# 17  {'Nombre del grupo': 'Grupo de Investigación e...
# 18  {'Nombre del grupo': 'Productos Naturales Mari...
# 19  {'Nombre del grupo': 'GeoLimna', 'Nombre del l...
# 20  {'Nombre del grupo': 'FITOBIOL', 'Nombre del l...
#
#                                            Info_group  \
# 10  {'Fecha de última actualización': '(Fecha de ú...
# 11  {'Fecha de última actualización': '(Fecha de ú...
# 12  {'Fecha de última actualización': '(Fecha de ú...
# 13  {'Fecha de última actualización': '(Fecha de ú...
# ...

# %%
df.loc[14]
# Out:
# Group                        {'Nombre del grupo': 'Colombia: tradiciones de...
# Info_group                   {'Fecha de última actualización': '(Fecha de ú...
# Members                      [{'Integrante': 'Guzmán Méndez Diana Paola', '...
# NC_P-ART_IMP_P               [{'Título del artículo': 'El cuento colombiano...
# NC_P-ART_ELE_P               [{'Título del artículo': 'Cuento ilustrado. Cu...
# NC_P-CAP_LIB_P               [{'Título del capítulo del libro': 'Tomás Carr...
# ASC_P-GEN_CONT_IMP_P1        [{'Tipo de producto': 'Reseña de libro', 'Nomb...
# ASC_P-EV_CIENT_P             [{'Nombre': 'VII Coloquio Internacional de his...
# ASC_P-RED_P                  [{'Nombre': 'ELADD Escritoras Latinoamericanas...
# ASC_P-INF_TEC_P                                                            NaN
# FRH_P-TES_DOC_P                                                            NaN
# FRH_P-TES_MAST_P                                                           NaN
# ...

# %%
len(['NC_P-ART_df.loc[14]IMP_P'])
# Out:
# 4

# %%
len(df.loc[19]['NC_P-ART_ELE_P'])
# Out:
# 17

# %%
len(df.loc[19]['ASC_P-EV_CIENT_P'])
# Out:
# 32

# %%
df.loc[19]['ASC_P-EV_CIENT_P']
# Out:
# [{'Nombre': 'Taller Nacional presentación y discusión del Índice de Calidad Ecológico',
#   'Fecha de inicio': '2014-04-22',
#   'Fecha de finalización': '2014-04-22',
#   'Participantes': '0',
#   'Instituciones': '1',
#   'Categoría': 'EC_B',
#   'Última actualización': '2017-12-06'},
#  {'Nombre': 'II CONGRESO NACIONAL Y III LATINOAMERICANO DE ALTA MONTAÑA TROPICAL: EFECTOS DE LOS DISTURBIOS ANTRÓPICOS SOBRE LOS ECOSSITEMAS ALTOANDINOS, PARÁMOS Y GLACIARES',
#   'Fecha de inicio': '2016-10-24',
#   'Fecha de finalización': '2016-10-29',
#   'Participantes': '0',
#   'Instituciones': '1',
#   'Categoría': 'EC_A',
#   'Última actualización': '2017-12-06'},
#  {'Nombre': 'XI CONGRESO DE FICOLOGÍA DE LATINOAMERICANA Y EL CARIBE',
#   'Fecha de inicio': '2017-11-05',
#   'Fecha de finalización': '2017-11-10',
#   'Participantes': '0',
#   'Instituciones': '1',
#   'Categoría': 'EC_A',
#   'Última actualización': '2019-02-08'},
# ...
